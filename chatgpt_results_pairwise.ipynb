# %%
import json
import pandas as pd

# Load the JSON data
with open('results/ChatGPT/intermediate_results/chatgpt_hierarchical_pairwise.json', 'r') as file:
    data = json.load(file)
    
lvl1 = len(['natural sciences', 'engineering and technology', 'agricultural sciences', 'medical and health sciences', 'social sciences', 'humanities'])-1
lvl12 = json.load(open('discipline_structure.json', 'r'))
lvl12 = {key: len(list(values.keys()))-1 for key, values in lvl12.items()}

# Initialize a list to store the results
results = []

# Iterate through each PUBID and its categories
for pubid, categories in data.items():
    # Initialize a list to store the disciplines with a final score above 0.5
    retained_disciplines = []
    highest_score = 0
    highest_discipline = None
    
    for category, details in categories.items():
        category_score = float(details['score']) / lvl1
        # Sort disciplines by their final score in descending order
        sorted_disciplines = sorted(details['subdisciplines'].items(), key=lambda x: float(x[1]) / 100 * category_score, reverse=True)
        
        added_disciplines = 0  # Counter for added disciplines per category
        for discipline, score in sorted_disciplines:
            final_score = category_score * float(score) / lvl12[category]
            # Check if the final score is above 0.5 and limit to top 3 per category
            if final_score >= 0.6: #and added_disciplines < 3:
                retained_disciplines.append(discipline)
                
                if pubid == '516167800001':
                    print(discipline, final_score)
                added_disciplines += 1
            # Update the highest score discipline if no discipline is above 0.5
            if final_score > highest_score:
                highest_score = final_score
                highest_discipline = discipline
                
                
    # If no discipline has a final score above 0.5, add the discipline with the highest score
    if not retained_disciplines and highest_discipline:
        retained_disciplines.append(highest_discipline)
    
    # Append the result
    results.append({'PUBID': pubid, 'chatgpt': retained_disciplines})

# Convert the results to a DataFrame
results_df = pd.DataFrame(results)

results_df
# Out:
# industrial biotechnology 1.0
# chemical engineering 0.8
# materials engineering 0.8
# environmental biotechnology 0.6
# biological sciences 0.8000000000000002
# earth and related environmental sciences 0.6666666666666666
#             PUBID                                            chatgpt
# 0    486688800001  [civil engineering, electrical engineering, el...
# 1    490689400001  [agriculture, forestry, and fisheries, animal ...
# 2    494013500001  [media and communications, law, political scie...
# 3    497937300001  [agriculture, forestry, and fisheries, other a...
# 4    500234900001  [materials engineering, nano-technology, liter...
# ..            ...                                                ...
# 186  843237200001                [clinical medicine, basic medicine]
# 187  866351500058  [basic medicine, clinical medicine, biological...
# 188  871947700028  [clinical medicine, health sciences, sociology...
# 189  755547200001  [electrical engineering, electronic engineerin...
# 190  691152500001  [civil engineering, electrical engineering, el...
#
# [191 rows x 2 columns]

# %%
lvl1
# Out:
# 5

# %%
data['500234900001']
# Out:
# {'agricultural sciences': {'score': 0, 'subdisciplines': {}},
#  'engineering and technology': {'score': 4,
#   'subdisciplines': {'civil engineering': 7,
#    'electrical engineering, electronic engineering, information engineering': 6,
#    'mechanical engineering': 4,
#    'chemical engineering': 1,
#    'materials engineering': 8,
#    'medical engineering': 5,
#    'environmental engineering': 4,
#    'environmental biotechnology': 1,
#    'industrial biotechnology': 4,
#    'nano-technology': 8,
#    'other engineering and technologies': 7}},
#  'humanities': {'score': 4,
#   'subdisciplines': {'history': 4,
#    'archaeology': 0,
#    'languages and linguistics': 2,
#    'literature': 7,
#    'philosophy and ethics': 4,
#    'religion': 4,
#    'arts (arts, history of arts, performing arts, music)': 6,
#    'other humanities': 1}},
#  'medical and health sciences': {'score': 2, 'subdisciplines': {}},
#  'natural sciences': {'score': 1, 'subdisciplines': {}},
#  'social sciences': {'score': 4,
#   'subdisciplines': {'psychology': 4,
#    'economics and business': 5,
#    'educational sciences': 2,
#    'sociology': 5,
#    'law': 4,
#    'political science': 1,
#    'social and economic geography': 3,
#    'media and communications': 8,
#    'other social sciences': 4}}}

# %%
results_df['prediction_length'] = results_df.chatgpt.apply(len)

# %%
results_df.prediction_length.value_counts()
# Out:
# prediction_length
# 4    53
# 5    47
# 6    39
# 7    25
# 3    12
# 2    12
# 8     2
# 1     1
# Name: count, dtype: int64

# %%
import pandas as pd
test_data = pd.read_csv('H:/data/WoS_data/data_gpt10.csv', usecols=['PUBID', 'ABSTRACT', 'final_disciplines'], dtype=str)

# %%
test_data = test_data.merge(results_df, on='PUBID')

# %%
test_data['final_disciplines'] = test_data.final_disciplines.str.lower()
replace_dict = {
    'arts (arts, history of arts, performing arts, music)':'art (arts, history of arts, performing arts, music)'
}
test_data['chatgpt'] = test_data.chatgpt.apply(lambda x: list(set(replace_dict.get(y,y) for y in x)))
data = test_data

# %%
data['final_disciplines'] = data.final_disciplines.apply(lambda x: x.split(';'))

# %%
data['arts'] = data.chatgpt.apply(lambda x: any(el.startswith('art') for el in x))

# %%
data[data.arts]
# Out:
#             PUBID                                           ABSTRACT  \
# 4    500234900001  Glamour is usually theorized within fashion st...
# 5    515343800001  The article intends to give a synoptic view of...
# 7    521535000001  This paper contributes to a theoretical discus...
# 8    524076900001  This paper provides a qualitative account of V...
# 21   592416200001  This paper develops a framework based on categ...
# 27   611026300001  When its entire staff resigned in protest of m...
# 30   619768700001  Cinematic studies support that the fiction fil...
# 33   624081100001  This article examines life writing as a resear...
# 41   639517000001  Supported by an environment that is increasing...
# 66   670822100001  The task of archaeologists is to study the mat...
# 91   689493100001  This essay examines how, through narrating the...
# 98   692312400001  Uniqlo, Japan's largest fashion brand, operate...
# 117  705812000002  Why disdain (perfectly) replicated art? If art...
# 134  716811800001  Reviewing the Old Vic's 1947 production of Ric...
# 168  759754900017  The author traces her development as a scholar...
# 169  766632100002  What is the classic in history? What is a clas...
# 173  778652100001  Chinese painted enamel is an artistic traditio...
# 177  788087800008  The present essay explores the question of con...
# 184  819041800001  The article contains the first edition of a hy...
#
#                                      final_disciplines  \
# 4    [literature, physical sciences, other humaniti...
# 5    [archaeology, art (arts, history of arts, perf...
# 7    [other humanities, media and communications, a...
# 8    [languages and linguistics, educational scienc...
# 21   [art (arts, history of arts, performing arts, ...
# 27   [art (arts, history of arts, performing arts, ...
# 30   [sociology, other humanities, psychology, othe...
# 33                                  [other humanities]
# 41   [computer and information sciences, media and ...
# 66   [sociology, other humanities, computer and inf...
# 91                      [literature, other humanities]
# 98   [political science, social and economic geogra...
# 117  [art (arts, history of arts, performing arts, ...
# 134  [philosophy and ethics, sociology, literature,...
# 168  [clinical medicine, literature, art (arts, his...
# 169                              [history, literature]
# 173  [other engineering and technologies, archaeolo...
# 177  [history, religion, archaeology, languages and...
# 184  [other social sciences, archaeology, history, ...
#
#                                                chatgpt  prediction_length  \
# 4    [literature, media and communications, nano-te...                  5
# 5    [other social sciences, media and communicatio...                  6
# 7    [literature, other social sciences, sociology,...                  6
# 8    [other social sciences, sociology, media and c...                  6
# 21   [literature, art (arts, history of arts, perfo...                  5
# 27   [literature, other humanities, other social sc...                  6
# 30   [literature, sociology, media and communicatio...                  5
# 33   [literature, sociology, media and communicatio...                  5
# 41   [literature, art (arts, history of arts, perfo...                  6
# 66   [media and communications, archaeology, art (a...                  5
# 91   [art (arts, history of arts, performing arts, ...                  2
# 98   [art (arts, history of arts, performing arts, ...                  4
# 117  [literature, psychology, other social sciences...                  5
# 134  [art (arts, history of arts, performing arts, ...                  4
# 168  [literature, sociology, religion, media and co...                  6
# 169  [literature, basic medicine, clinical medicine...                  5
# 173  [materials engineering, history, civil enginee...                  6
# 177  [art (arts, history of arts, performing arts, ...                  4
# 184  [basic medicine, clinical medicine, religion, ...                  6
#
#      arts
# 4    True
# 5    True
# 7    True
# 8    True
# 21   True
# 27   True
# 30   True
# 33   True
# 41   True
# 66   True
# 91   True
# 98   True
# 117  True
# 134  True
# 168  True
# 169  True
# 173  True
# 177  True
# 184  True

# %%
data
# Out:
#             PUBID                                           ABSTRACT  \
# 0    486688800001  In this paper, we first study the theory of th...
# 1    490689400001  Babassu is a palm tree that occupies a vast ar...
# 2    494013500001  This study, from a sociosemiotic perspective, ...
# 3    497937300001  The effects of four deferred grazing strategie...
# 4    500234900001  Glamour is usually theorized within fashion st...
# ..            ...                                                ...
# 186  831664900001  The question of women's ordination to offices ...
# 187  833337700001  Recent studies on the Buddhist threefold wisdo...
# 188  843237200001  The article presents Ignatian (Jesuit) spiritu...
# 189  866351500058  Administration of human umbilical cord-derived...
# 190  871947700028  Beginning in earnest in the 1990s, archaeologi...
#
#                                      final_disciplines  \
# 0    [mathematics, biological sciences, earth and r...
# 1    [agriculture, forestry, and fisheries, animal ...
# 2    [sociology, other humanities, languages and li...
# 3    [animal and dairy science, veterinary science,...
# 4    [literature, physical sciences, other humaniti...
# ..                                                 ...
# 186                                [history, religion]
# 187  [other social sciences, philosophy and ethics,...
# 188  [educational sciences, religion, health sciences]
# 189  [basic medicine, health biotechnology, biologi...
# 190                           [archaeology, sociology]
#
#                                                chatgpt  prediction_length  \
# 0    [earth and related environmental sciences, civ...                  5
# 1    [agriculture, forestry, and fisheries, basic m...                  4
# 2    [political science, media and communications, ...                  3
# 3    [agriculture, forestry, and fisheries, basic m...                  4
# 4    [literature, media and communications, nano-te...                  5
# ..                                                 ...                ...
# 186  [other social sciences, sociology, media and c...                  5
# 187  [religion, basic medicine, clinical medicine, ...                  4
# 188                [basic medicine, clinical medicine]                  2
# 189  [basic medicine, clinical medicine, biological...                  4
# 190  [other social sciences, clinical medicine, hea...                  6
#
#       arts
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# ..     ...
# 186  False
# 187  False
# 188  False
# 189  False
# 190  False
#
# [191 rows x 6 columns]

# %%
from sklearn.preprocessing import MultiLabelBinarizer
true_labels = list(data.final_disciplines)
predicted_labels = list(data.chatgpt)
mlb = MultiLabelBinarizer()
true_label_binarized = mlb.fit_transform(true_labels)
predicted_labels_binarized = mlb.transform(predicted_labels)
from sklearn.metrics import classification_report
print(classification_report(true_label_binarized, predicted_labels_binarized, target_names=mlb.classes_))
# Out:
#                                                                          precision    recall  f1-score   support
#
#                                    agriculture, forestry, and fisheries       0.42      0.50      0.45        10
#                                                animal and dairy science       0.91      0.71      0.80        14
#                                                             archaeology       0.78      0.58      0.67        12
#                     art (arts, history of arts, performing arts, music)       0.42      0.57      0.48        14
#                                                          basic medicine       0.25      0.94      0.40        17
#                                                     biological sciences       0.57      0.62      0.60        32
#                                                    chemical engineering       0.43      0.82      0.56        11
#                                                       chemical sciences       0.69      0.30      0.42        30
#                                                       civil engineering       0.36      0.94      0.52        16
#                                                       clinical medicine       0.28      0.95      0.43        20
#                                       computer and information sciences       0.12      0.15      0.13        13
#                                earth and related environmental sciences       0.26      0.59      0.36        17
#                                                  economics and business       0.47      0.47      0.47        17
#                                                    educational sciences       0.27      0.30      0.29        10
# electrical engineering, electronic engineering, information engineering       0.17      0.80      0.28        10
#                                             environmental biotechnology       1.00      0.07      0.13        14
#                                               environmental engineering       0.00      0.00      0.00        18
#                                                    health biotechnology       0.00      0.00      0.00        10
#                                                         health sciences       0.13      0.20      0.16        10
#                                                                 history       0.41      0.50      0.45        14
#                                                industrial biotechnology       0.18      0.25      0.21        12
#                                               languages and linguistics       0.67      0.15      0.25        13
#                                                                     law       0.44      0.73      0.55        11
#                                                              literature       0.37      0.58      0.45        12
#                                                   materials engineering       0.30      0.95      0.45        22
#                                                             mathematics       0.60      0.21      0.32        14
#                                                  mechanical engineering       0.29      0.83      0.43        12
#                                                media and communications       0.16      0.50      0.24        14
#                                                     medical engineering       0.23      1.00      0.38        11
#                                                         nano-technology       0.38      0.91      0.54        11
#                                             other agricultural sciences       0.00      0.00      0.00        12
#                                      other engineering and technologies       0.09      0.14      0.11        14
#                                                        other humanities       0.33      0.05      0.09        19
#                                                   other social sciences       0.14      0.36      0.21        11
#                                                   philosophy and ethics       0.43      0.30      0.35        10
#                                                       physical sciences       0.33      0.18      0.23        17
#                                                       political science       0.45      0.50      0.48        10
#                                                              psychology       0.60      0.60      0.60        15
#                                                                religion       0.69      0.69      0.69        13
#                                           social and economic geography       0.22      0.31      0.26        13
#                                                               sociology       0.46      0.53      0.49        30
#                                                      veterinary science       0.40      0.40      0.40        10
#
#                                                               micro avg       0.32      0.49      0.39       615
#                                                               macro avg       0.37      0.48      0.37       615
#                                                            weighted avg       0.39      0.49      0.38       615
#                                                             samples avg       0.33      0.50      0.38       615
# C:\Users\carhiliuc\Anaconda3\envs\univer\lib\site-packages\sklearn\preprocessing\_label.py:900: UserWarning: unknown class(es) ['agricultural biotechnology'] will be ignored
#   warnings.warn(

# %%
from sklearn.metrics import accuracy_score
accuracy_score(true_label_binarized, predicted_labels_binarized)
# Out:
# 0.0

# %%
mlb.classes_
# Out:
# array(['agriculture, forestry, and fisheries', 'animal and dairy science',
#        'archaeology',
#        'art (arts, history of arts, performing arts, music)',
#        'basic medicine', 'biological sciences', 'chemical engineering',
#        'chemical sciences', 'civil engineering', 'clinical medicine',
#        'computer and information sciences',
#        'earth and related environmental sciences',
#        'economics and business', 'educational sciences',
#        'electrical engineering, electronic engineering, information engineering',
#        'environmental biotechnology', 'environmental engineering',
#        'health biotechnology', 'health sciences', 'history',
#        'industrial biotechnology', 'languages and linguistics', 'law',
#        'literature', 'materials engineering', 'mathematics',
#        'mechanical engineering', 'media and communications',
#        'medical engineering', 'nano-technology',
#        'other agricultural sciences',
#        'other engineering and technologies', 'other humanities',
#        'other social sciences', 'philosophy and ethics',
#        'physical sciences', 'political science', 'psychology', 'religion',
#        'social and economic geography', 'sociology', 'veterinary science'],
#       dtype=object)

# %%
def filter_labels(labels_list):
    filtered_labels = []
    for labels in labels_list:
        filtered_labels.append([label for label in labels if not label.startswith('other')])
    return filtered_labels

# Filter both true and predicted labels
true_labels_filtered = filter_labels(list(data.final_disciplines))
predicted_labels_filtered = filter_labels(list(data.chatgpt))

# Initialize MultiLabelBinarizer
mlb = MultiLabelBinarizer()

# Transform labels
true_label_binarized = mlb.fit_transform(true_labels_filtered)
predicted_labels_binarized = mlb.transform(predicted_labels_filtered)

# Generate and print classification report
print(classification_report(true_label_binarized, predicted_labels_binarized, target_names=mlb.classes_))
# Out:
# C:\Users\carhiliuc\Anaconda3\envs\univer\lib\site-packages\sklearn\preprocessing\_label.py:900: UserWarning: unknown class(es) ['agricultural biotechnology'] will be ignored
#   warnings.warn(
#                                                                          precision    recall  f1-score   support
#
#                                    agriculture, forestry, and fisheries       0.42      0.50      0.45        10
#                                                animal and dairy science       0.91      0.71      0.80        14
#                                                             archaeology       0.78      0.58      0.67        12
#                     art (arts, history of arts, performing arts, music)       0.42      0.57      0.48        14
#                                                          basic medicine       0.25      0.94      0.40        17
#                                                     biological sciences       0.57      0.62      0.60        32
#                                                    chemical engineering       0.43      0.82      0.56        11
#                                                       chemical sciences       0.69      0.30      0.42        30
#                                                       civil engineering       0.36      0.94      0.52        16
#                                                       clinical medicine       0.28      0.95      0.43        20
#                                       computer and information sciences       0.12      0.15      0.13        13
#                                earth and related environmental sciences       0.26      0.59      0.36        17
#                                                  economics and business       0.47      0.47      0.47        17
#                                                    educational sciences       0.27      0.30      0.29        10
# electrical engineering, electronic engineering, information engineering       0.17      0.80      0.28        10
#                                             environmental biotechnology       1.00      0.07      0.13        14
#                                               environmental engineering       0.00      0.00      0.00        18
#                                                    health biotechnology       0.00      0.00      0.00        10
#                                                         health sciences       0.13      0.20      0.16        10
#                                                                 history       0.41      0.50      0.45        14
#                                                industrial biotechnology       0.18      0.25      0.21        12
#                                               languages and linguistics       0.67      0.15      0.25        13
#                                                                     law       0.44      0.73      0.55        11
#                                                              literature       0.37      0.58      0.45        12
#                                                   materials engineering       0.30      0.95      0.45        22
#                                                             mathematics       0.60      0.21      0.32        14
#                                                  mechanical engineering       0.29      0.83      0.43        12
#                                                media and communications       0.16      0.50      0.24        14
#                                                     medical engineering       0.23      1.00      0.38        11
#                                                         nano-technology       0.38      0.91      0.54        11
#                                                   philosophy and ethics       0.43      0.30      0.35        10
#                                                       physical sciences       0.33      0.18      0.23        17
#                                                       political science       0.45      0.50      0.48        10
#                                                              psychology       0.60      0.60      0.60        15
#                                                                religion       0.69      0.69      0.69        13
#                                           social and economic geography       0.22      0.31      0.26        13
#                                                               sociology       0.46      0.53      0.49        30
#                                                      veterinary science       0.40      0.40      0.40        10
#
#                                                               micro avg       0.34      0.53      0.41       559
#                                                               macro avg       0.40      0.52      0.39       559
#                                                            weighted avg       0.41      0.53      0.40       559
#                                                             samples avg       0.35      0.54      0.40       559
# C:\Users\carhiliuc\Anaconda3\envs\univer\lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in samples with no true labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
data[data.PUBID == '516167800001'].final_disciplines.values
# Out:
# array([list(['other agricultural sciences', 'environmental biotechnology', 'environmental engineering', 'chemical sciences'])],
#       dtype=object)

# %%
data[data.PUBID == '516167800001'].chatgpt.values
# Out:
# array([list(['environmental biotechnology', 'chemical engineering', 'industrial biotechnology', 'earth and related environmental sciences', 'biological sciences', 'materials engineering'])],
#       dtype=object)
