# %%
import pandas as pd
from ast import literal_eval

# %%
import json
with open('discipline_structure.json', 'r') as f:
    data = json.load(f)
data_simplified = {key1: list(value.keys()) for key1, value in data.items()}
data_simplified_reversed = {el:key for key, value in data_simplified.items() for el in value}

def get_area(discipline):
    discipline = discipline.replace('Art', 'Arts').replace('art ', 'arts ').replace('Eartsh', 'Earth')
    return data_simplified_reversed[discipline.lower()] if discipline.lower() in data_simplified_reversed else discipline

# %%
def describe_area(df: pd.DataFrame, train=False, limit=500000):
    df_exploded = df.explode('final_disciplines')
    df_exploded['area'] = df_exploded.final_disciplines.apply(get_area)
    total_disciplines_over_threshold = 0
    for area in df_exploded.area.unique():
        print(f'---------------------- \n {area}')
        area_df = df_exploded[df_exploded.area == area].drop_duplicates()        
        print(f'Disciplines: {list(area_df.final_disciplines.unique())}')
        grouped_area = area_df.groupby('final_disciplines').agg({'ABSTRACT': 'count', 'len_final': 'mean'})
        print(f'Count information \n {grouped_area.ABSTRACT.describe()}')
        print(f'Nb labels information \n {grouped_area.len_final.describe()}')
        if train:
            disciplines_over_threshold = grouped_area[grouped_area.ABSTRACT >= limit].shape[0]
            total_disciplines_over_threshold += disciplines_over_threshold
            print(f'Nb disciplines that get to the limit: {disciplines_over_threshold}')
    print(f'Total disciplines over threshold: {total_disciplines_over_threshold}')

def prep_train(df):
    df['label'] = df.label.apply(literal_eval)
    df['len_final'] = df.label.apply(len)
    return df.rename(columns={'text': 'ABSTRACT', 'label':'final_disciplines'})

# %% [markdown]
# ## Total data

# %%
total = pd.read_pickle('data_to_be_split.pickle')

# %%
total
# Out:
#                                                   ABSTRACT  \
# 0        In recent decades, racial disparities in K-12 ...
# 1        A medium ash coal is used for the study. Four ...
# 2        The separation of coal and gangue is an import...
# 3        Two different stockpiles, one loose and anothe...
# 4        Family leisure is a context in which individua...
# ...                                                    ...
# 2119147  The Pacific Ocean is the largest in the world,...
# 2119148  We have extended the Helfrich's spontaneous cu...
# 2119149  Modern cosmology is broadly based on the Cosmo...
# 2119150  Using the data from the Chinese Household Inco...
# 2119151  Ratner et al. (2022) and Silver and Small (202...
#
#                                          final_disciplines  len_final
# 0        [Psychology, Sociology, Educational sciences, ...          4
# 1        [Chemical engineering, Earth and related envir...          4
# 2        [Computer and information sciences, Electrical...          5
# 3        [Environmental engineering, Chemical engineeri...          5
# 4        [Other social sciences, Sociology, Media and c...          4
# ...                                                    ...        ...
# 2119147                              [Biological sciences]          1
# 2119148  [Physical sciences, Mathematics, Chemical scie...          3
# 2119149                                [Physical sciences]          1
# 2119150                           [Economics and business]          1
# 2119151                                       [Psychology]          1
#
# [2077486 rows x 3 columns]

# %%
total.len_final.describe()
# Out:
# count    2.077486e+06
# mean     2.412943e+00
# std      1.158512e+00
# min      1.000000e+00
# 25%      1.000000e+00
# 50%      2.000000e+00
# 75%      3.000000e+00
# max      5.000000e+00
# Name: len_final, dtype: float64

# %%
describe_area(total)
# Out:
# ----------------------
#  social sciences
# Disciplines: ['Psychology', 'Sociology', 'Educational sciences', 'Law', 'Other social sciences', 'Media and communications', 'Economics and business', 'Social and economic geography', 'Political Science']
# Count information
#  count         9.000000
# mean      54498.444444
# std       47016.739009
# min       10588.000000
# 25%       18050.000000
# 50%       35842.000000
# 75%       70671.000000
# max      130365.000000
# Name: ABSTRACT, dtype: float64
# Nb labels information
#  count    9.000000
# mean     3.047019
# std      0.247800
# min      2.730286
# 25%      2.796560
# 50%      3.029940
# 75%      3.205651
# max      3.397027
# Name: len_final, dtype: float64
# ----------------------
#  engineering and technology
# Disciplines: ['Chemical engineering', 'Environmental engineering', 'Electrical engineering, electronic engineering, information engineering', 'Materials engineering', 'Other engineering and technologies', 'Nano-technology', 'Environmental biotechnology', 'Mechanical engineering', 'Civil engineering', 'Medical engineering', 'Industrial Biotechnology']
# Count information
#  count        11.000000
# mean     114281.818182
# std       85886.507395
# min        8603.000000
# 25%       52081.000000
# 50%       86641.000000
# 75%      180926.000000
# max      276655.000000
# Name: ABSTRACT, dtype: float64
# Nb labels information
#  count    11.000000
# mean      3.511931
# std       0.335007
# min       2.889713
# 25%       3.342591
# 50%       3.447743
# 75%       3.668279
# max       4.200332
# Name: len_final, dtype: float64
# ----------------------
#  natural sciences
# Disciplines: ['Earth and related environmental sciences', 'Chemical sciences', 'Computer and information sciences', 'Physical sciences', 'Mathematics', 'Biological sciences']
# Count information
#  count         6.000000
# mean     297302.833333
# std      144378.831367
# min      110198.000000
# 25%      204983.250000
# 50%      297808.000000
# 75%      368288.750000
# max      512179.000000
# Name: ABSTRACT, dtype: float64
# Nb labels information
#  count    6.000000
# mean     2.905552
# std      0.285276
# min      2.513476
# 25%      2.686150
# 50%      2.992563
# 75%      3.100410
# max      3.214340
# Name: len_final, dtype: float64
# ----------------------
#  medical and health sciences
# Disciplines: ['Clinical medicine', 'Health sciences', 'Basic medicine', 'Health biotechnology']
# Count information
#  count         4.000000
# mean     313161.500000
# std      258813.425801
# min        1737.000000
# 25%      197493.750000
# 50%      311367.000000
# 75%      427034.750000
# max      628175.000000
# Name: ABSTRACT, dtype: float64
# Nb labels information
#  count    4.000000
# mean     2.987603
# std      0.727032
# min      2.249580
# 25%      2.663529
# 50%      2.856460
# 75%      3.180534
# max      3.987910
# Name: len_final, dtype: float64
# ----------------------
#  humanities
# Disciplines: ['Languages and linguistics', 'History', 'Other humanities', 'Literature', 'Art (arts, history of arts, performing arts, music)', 'Philosophy and ethics', 'Religion', 'Archaeology']
# Count information
#  count        8.000000
# mean      7019.750000
# std       4907.354357
# min       2499.000000
# 25%       3142.750000
# 50%       5037.000000
# 75%      10672.750000
# max      15935.000000
# Name: ABSTRACT, dtype: float64
# Nb labels information
#  count    8.000000
# mean     2.865547
# std      0.263137
# min      2.539346
# 25%      2.656289
# 50%      2.838120
# 75%      3.085614
# max      3.246941
# Name: len_final, dtype: float64
# ----------------------
#  agricultural sciences
# Disciplines: ['Animal and dairy science', 'Veterinary science', 'Other agricultural sciences', 'Agriculture, forestry, and fisheries']
# Count information
#  count        4.000000
# mean     23877.000000
# std      24858.857308
# min       7505.000000
# 25%       9371.000000
# 50%      13686.000000
# 75%      28192.000000
# max      60631.000000
# Name: ABSTRACT, dtype: float64
# Nb labels information
#  count    4.000000
# mean     3.136232
# std      0.626986
# min      2.769639
# 25%      2.807290
# 50%      2.850536
# 75%      3.179479
# max      4.074217
# Name: len_final, dtype: float64
# ----------------------
#  Multidisicplinary
# Disciplines: ['Multidisicplinary']
# Count information
#  count        1.0
# mean     73423.0
# std          NaN
# min      73423.0
# 25%      73423.0
# 50%      73423.0
# 75%      73423.0
# max      73423.0
# Name: ABSTRACT, dtype: float64
# Nb labels information
#  count    1.00000
# mean     3.23099
# std          NaN
# min      3.23099
# 25%      3.23099
# 50%      3.23099
# 75%      3.23099
# max      3.23099
# Name: len_final, dtype: float64
# Total disciplines over threshold: 0

# %% [markdown]
# ## Train 100k

# %%
train100k = pd.read_csv('different_size/train100000.csv')

# %%
train100k = prep_train(train100k)

# %%
train100k.len_final.describe()
# Out:
# count    736432.000000
# mean          2.761121
# std           1.180125
# min           1.000000
# 25%           2.000000
# 50%           3.000000
# 75%           4.000000
# max          22.000000
# Name: len_final, dtype: float64

# %%
describe_area(train100k, True, 100000)
# Out:
# ----------------------
#  social sciences
# Disciplines: ['Psychology', 'Educational sciences', 'Sociology', 'Social and economic geography', 'Political Science', 'Other social sciences', 'Economics and business', 'Law', 'Media and communications']
# Count information
#  count        9.000000
# mean     32703.222222
# std      28215.845290
# min       6352.000000
# 25%      10828.000000
# 50%      21507.000000
# 75%      42412.000000
# max      78235.000000
# Name: ABSTRACT, dtype: float64
# Nb labels information
#  count    9.000000
# mean     3.030681
# std      0.244368
# min      2.732302
# 25%      2.784857
# 50%      2.998898
# 75%      3.189215
# max      3.386410
# Name: len_final, dtype: float64
# Nb disciplines that get to the limit: 0
# ----------------------
#  medical and health sciences
# Disciplines: ['Health sciences', 'Basic medicine', 'Clinical medicine', 'Health biotechnology']
# Count information
#  count         4.000000
# mean      84315.500000
# std       57317.425102
# min        1023.000000
# 25%       75234.750000
# 50%      102108.500000
# 75%      111189.250000
# max      132022.000000
# Name: ABSTRACT, dtype: float64
# Nb labels information
#  count    4.000000
# mean     3.262713
# std      0.442779
# min      2.901266
# 25%      3.008606
# 50%      3.124647
# 75%      3.378754
# max      3.900293
# Name: len_final, dtype: float64
# Nb disciplines that get to the limit: 2
# ----------------------
#  natural sciences
# Disciplines: ['Chemical sciences', 'Earth and related environmental sciences', 'Biological sciences', 'Computer and information sciences', 'Physical sciences', 'Mathematics']
# Count information
#  count         6.000000
# mean     108050.000000
# std       24823.711544
# min       66131.000000
# 25%      100674.000000
# 50%      109525.000000
# 75%      123958.250000
# max      136626.000000
# Name: ABSTRACT, dtype: float64
# Nb labels information
#  count    6.000000
# mean     3.232371
# std      0.479246
# min      2.479336
# 25%      3.053455
# 50%      3.197964
# 75%      3.593760
# max      3.787984
# Name: len_final, dtype: float64
# Nb disciplines that get to the limit: 5
# ----------------------
#  engineering and technology
# Disciplines: ['Other engineering and technologies', 'Environmental engineering', 'Chemical engineering', 'Electrical engineering, electronic engineering, information engineering', 'Nano-technology', 'Materials engineering', 'Mechanical engineering', 'Civil engineering', 'Medical engineering', 'Industrial Biotechnology', 'Environmental biotechnology']
# Count information
#  count        11.000000
# mean      60134.727273
# std       38774.066581
# min        5141.000000
# 25%       31256.000000
# 50%       51877.000000
# 75%      100365.000000
# max      108675.000000
# Name: ABSTRACT, dtype: float64
# Nb labels information
#  count    11.000000
# mean      3.549903
# std       0.315932
# min       3.026174
# 25%       3.313456
# 50%       3.601188
# 75%       3.731992
# max       4.145363
# Name: len_final, dtype: float64
# Nb disciplines that get to the limit: 4
# ----------------------
#  humanities
# Disciplines: ['History', 'Languages and linguistics', 'Art (arts, history of arts, performing arts, music)', 'Philosophy and ethics', 'Religion', 'Other humanities', 'Literature', 'Archaeology']
# Count information
#  count       8.000000
# mean     4212.500000
# std      2945.159418
# min      1500.000000
# 25%      1885.250000
# 50%      3023.000000
# 75%      6404.000000
# max      9563.000000
# Name: ABSTRACT, dtype: float64
# Nb labels information
#  count    8.000000
# mean     2.854105
# std      0.242007
# min      2.556833
# 25%      2.660722
# 50%      2.825817
# 75%      3.088064
# max      3.151151
# Name: len_final, dtype: float64
# Nb disciplines that get to the limit: 0
# ----------------------
#  agricultural sciences
# Disciplines: ['Agriculture, forestry, and fisheries', 'Animal and dairy science', 'Veterinary science', 'Other agricultural sciences']
# Count information
#  count        4.000000
# mean     14328.250000
# std      14916.221514
# min       4504.000000
# 25%       5624.500000
# 50%       8213.500000
# 75%      16917.250000
# max      36382.000000
# Name: ABSTRACT, dtype: float64
# Nb labels information
#  count    4.000000
# mean     3.120669
# std      0.630724
# min      2.756586
# 25%      2.798553
# 50%      2.830519
# 75%      3.152636
# max      4.065053
# Name: len_final, dtype: float64
# Nb disciplines that get to the limit: 0
# Total disciplines over threshold: 11

# %% [markdown]
# ## Train 10k

# %%
train10k = pd.read_csv('different_size/train10000.csv')

# %%
train10k = prep_train(train10k)

# %%
train10k.len_final.describe()
# Out:
# count    158433.000000
# mean          2.910606
# std           1.254986
# min           1.000000
# 25%           2.000000
# 50%           3.000000
# 75%           4.000000
# max          17.000000
# Name: len_final, dtype: float64

# %%
describe_area(train10k, True, 10000)
# Out:
# ----------------------
#  humanities
# Disciplines: ['History', 'Languages and linguistics', 'Art (arts, history of arts, performing arts, music)', 'Philosophy and ethics', 'Religion', 'Other humanities', 'Literature', 'Archaeology']
# Count information
#  count       8.000000
# mean     4212.500000
# std      2945.159418
# min      1500.000000
# 25%      1885.250000
# 50%      3023.000000
# 75%      6404.000000
# max      9563.000000
# Name: ABSTRACT, dtype: float64
# Nb labels information
#  count    8.000000
# mean     2.854105
# std      0.242007
# min      2.556833
# 25%      2.660722
# 50%      2.825817
# 75%      3.088064
# max      3.151151
# Name: len_final, dtype: float64
# Nb disciplines that get to the limit: 0
# ----------------------
#  social sciences
# Disciplines: ['Educational sciences', 'Sociology', 'Political Science', 'Other social sciences', 'Psychology', 'Social and economic geography', 'Economics and business', 'Law', 'Media and communications']
# Count information
#  count        9.000000
# mean     11871.777778
# std       4432.025405
# min       6352.000000
# 25%      10062.000000
# 50%      10124.000000
# 75%      16818.000000
# max      17735.000000
# Name: ABSTRACT, dtype: float64
# Nb labels information
#  count    9.000000
# mean     3.190652
# std      0.237196
# min      2.866456
# 25%      2.998898
# 50%      3.236239
# 75%      3.301438
# max      3.574541
# Name: len_final, dtype: float64
# Nb disciplines that get to the limit: 7
# ----------------------
#  medical and health sciences
# Disciplines: ['Health sciences', 'Basic medicine', 'Clinical medicine', 'Health biotechnology']
# Count information
#  count        4.000000
# mean     11862.750000
# std       7616.987741
# min       1023.000000
# 25%       9560.250000
# 50%      14071.000000
# 75%      16373.500000
# max      18286.000000
# Name: ABSTRACT, dtype: float64
# Nb labels information
#  count    4.000000
# mean     3.630028
# std      0.206256
# min      3.445149
# 25%      3.483142
# 50%      3.587335
# 75%      3.734222
# max      3.900293
# Name: len_final, dtype: float64
# Nb disciplines that get to the limit: 3
# ----------------------
#  natural sciences
# Disciplines: ['Computer and information sciences', 'Chemical sciences', 'Biological sciences', 'Physical sciences', 'Earth and related environmental sciences', 'Mathematics']
# Count information
#  count        6.000000
# mean     19288.833333
# std       6290.741973
# min      10570.000000
# 25%      16015.750000
# 50%      18899.500000
# 75%      22754.500000
# max      28270.000000
# Name: ABSTRACT, dtype: float64
# Nb labels information
#  count    6.000000
# mean     3.518788
# std      0.446382
# min      2.756102
# 25%      3.361766
# 50%      3.588511
# 75%      3.825237
# max      3.989273
# Name: len_final, dtype: float64
# Nb disciplines that get to the limit: 6
# ----------------------
#  agricultural sciences
# Disciplines: ['Animal and dairy science', 'Veterinary science', 'Other agricultural sciences', 'Agriculture, forestry, and fisheries']
# Count information
#  count        4.000000
# mean      7678.250000
# std       2869.253837
# min       4504.000000
# 25%       5624.500000
# 50%       8007.500000
# 75%      10061.250000
# max      10194.000000
# Name: ABSTRACT, dtype: float64
# Nb labels information
#  count    4.000000
# mean     3.184586
# std      0.605467
# min      2.756586
# 25%      2.803178
# 50%      2.958354
# 75%      3.339762
# max      4.065053
# Name: len_final, dtype: float64
# Nb disciplines that get to the limit: 2
# ----------------------
#  engineering and technology
# Disciplines: ['Other engineering and technologies', 'Medical engineering', 'Industrial Biotechnology', 'Materials engineering', 'Nano-technology', 'Civil engineering', 'Electrical engineering, electronic engineering, information engineering', 'Environmental engineering', 'Mechanical engineering', 'Environmental biotechnology', 'Chemical engineering']
# Count information
#  count       11.000000
# mean     11491.818182
# std       3948.814982
# min       5141.000000
# 25%      10061.000000
# 50%      10441.000000
# 75%      11231.500000
# max      18975.000000
# Name: ABSTRACT, dtype: float64
# Nb labels information
#  count    11.000000
# mean      3.736888
# std       0.222998
# min       3.355168
# 25%       3.628020
# 50%       3.669756
# 75%       3.850931
# max       4.191009
# Name: len_final, dtype: float64
# Nb disciplines that get to the limit: 9
# Total disciplines over threshold: 27

# %% [markdown]
# ## Train 1k

# %%
train1k = pd.read_csv('different_size/train1000.csv')

# %%
train1k = prep_train(train1k)

# %%
train1k.len_final.describe()
# Out:
# count    20027.000000
# mean         3.002746
# std          1.256141
# min          1.000000
# 25%          2.000000
# 50%          3.000000
# 75%          4.000000
# max         10.000000
# Name: len_final, dtype: float64

# %%
describe_area(train1k, True, 1000)
# Out:
# ----------------------
#  medical and health sciences
# Disciplines: ['Clinical medicine', 'Health sciences', 'Basic medicine', 'Health biotechnology']
# Count information
#  count       4.000000
# mean     1721.750000
# std       624.741213
# min      1000.000000
# 25%      1414.000000
# 50%      1692.500000
# 75%      2000.250000
# max      2502.000000
# Name: ABSTRACT, dtype: float64
# Nb labels information
#  count    4.000000
# mean     3.772768
# std      0.165600
# min      3.562500
# 25%      3.679294
# 50%      3.810113
# 75%      3.903587
# max      3.908347
# Name: len_final, dtype: float64
# Nb disciplines that get to the limit: 4
# ----------------------
#  humanities
# Disciplines: ['Philosophy and ethics', 'Art (arts, history of arts, performing arts, music)', 'Other humanities', 'Literature', 'History', 'Religion', 'Languages and linguistics', 'Archaeology']
# Count information
#  count       8.000000
# mean     1076.000000
# std        28.953164
# min      1011.000000
# 25%      1073.250000
# 50%      1088.500000
# 75%      1091.750000
# max      1098.000000
# Name: ABSTRACT, dtype: float64
# Nb labels information
#  count    8.000000
# mean     3.015607
# std      0.236847
# min      2.618508
# 25%      2.824309
# 50%      3.104882
# 75%      3.188188
# max      3.256856
# Name: len_final, dtype: float64
# Nb disciplines that get to the limit: 8
# ----------------------
#  social sciences
# Disciplines: ['Political Science', 'Sociology', 'Law', 'Psychology', 'Other social sciences', 'Media and communications', 'Social and economic geography', 'Educational sciences', 'Economics and business']
# Count information
#  count       9.000000
# mean     1481.333333
# std       684.974817
# min      1005.000000
# 25%      1043.000000
# 50%      1070.000000
# 75%      1849.000000
# max      3025.000000
# Name: ABSTRACT, dtype: float64
# Nb labels information
#  count    9.000000
# mean     3.305748
# std      0.177933
# min      3.015920
# 25%      3.199802
# 50%      3.368394
# 75%      3.440992
# max      3.530520
# Name: len_final, dtype: float64
# Nb disciplines that get to the limit: 9
# ----------------------
#  agricultural sciences
# Disciplines: ['Animal and dairy science', 'Veterinary science', 'Agriculture, forestry, and fisheries', 'Other agricultural sciences']
# Count information
#  count       4.000000
# mean     1060.000000
# std        43.749286
# min      1026.000000
# 25%      1028.250000
# 50%      1047.000000
# 75%      1078.750000
# max      1120.000000
# Name: ABSTRACT, dtype: float64
# Nb labels information
#  count    4.000000
# mean     3.296437
# std      0.557010
# min      2.799107
# 25%      2.979660
# 50%      3.152476
# 75%      3.469253
# max      4.081690
# Name: len_final, dtype: float64
# Nb disciplines that get to the limit: 4
# ----------------------
#  natural sciences
# Disciplines: ['Earth and related environmental sciences', 'Mathematics', 'Computer and information sciences', 'Biological sciences', 'Chemical sciences', 'Physical sciences']
# Count information
#  count       6.000000
# mean     2188.166667
# std       957.537554
# min      1075.000000
# 25%      1504.500000
# 50%      2115.500000
# 75%      2743.000000
# max      3570.000000
# Name: ABSTRACT, dtype: float64
# Nb labels information
#  count    6.000000
# mean     3.589982
# std      0.427674
# min      2.825116
# 25%      3.485198
# 50%      3.677220
# 75%      3.845711
# max      4.037274
# Name: len_final, dtype: float64
# Nb disciplines that get to the limit: 6
# ----------------------
#  engineering and technology
# Disciplines: ['Industrial Biotechnology', 'Other engineering and technologies', 'Environmental biotechnology', 'Nano-technology', 'Materials engineering', 'Medical engineering', 'Environmental engineering', 'Chemical engineering', 'Mechanical engineering', 'Electrical engineering, electronic engineering, information engineering', 'Civil engineering']
# Count information
#  count      11.000000
# mean     1261.545455
# std       418.198604
# min      1000.000000
# 25%      1018.500000
# 50%      1080.000000
# 75%      1207.500000
# max      2090.000000
# Name: ABSTRACT, dtype: float64
# Nb labels information
#  count    11.000000
# mean      3.822140
# std       0.275518
# min       3.306481
# 25%       3.644712
# 50%       3.850360
# 75%       4.002551
# max       4.199814
# Name: len_final, dtype: float64
# Nb disciplines that get to the limit: 11
# Total disciplines over threshold: 42

# %% [markdown]
# ## Test

# %%
test = pd.read_csv('test_new.csv')

# %%
test = prep_train(test)

# %%
test.len_final.describe()
# Out:
# count    415262.000000
# mean          2.379009
# std           1.147415
# min           1.000000
# 25%           1.000000
# 50%           2.000000
# 75%           3.000000
# max          13.000000
# Name: len_final, dtype: float64

# %%
describe_area(test)
# Out:
# ----------------------
#  natural sciences
# Disciplines: ['Computer and information sciences', 'Earth and related environmental sciences', 'Biological sciences', 'Chemical sciences', 'Physical sciences', 'Mathematics']
# Count information
#  count         6.000000
# mean      59498.000000
# std       28896.699597
# min       22052.000000
# 25%       41015.000000
# 50%       59592.500000
# 75%       73724.000000
# max      102494.000000
# Name: ABSTRACT, dtype: float64
# Nb labels information
#  count    6.000000
# mean     2.859646
# std      0.295945
# min      2.470116
# 25%      2.616009
# 50%      2.961145
# 75%      3.055365
# max      3.177733
# Name: len_final, dtype: float64
# ----------------------
#  social sciences
# Disciplines: ['Other social sciences', 'Economics and business', 'Media and communications', 'Psychology', 'Educational sciences', 'Sociology', 'Social and economic geography', 'Political Science', 'Law']
# Count information
#  count        9.000000
# mean     10902.777778
# std       9406.322817
# min       2117.000000
# 25%       3611.000000
# 50%       7171.000000
# 75%      14140.000000
# max      26081.000000
# Name: ABSTRACT, dtype: float64
# Nb labels information
#  count    9.000000
# mean     3.030387
# std      0.250804
# min      2.684974
# 25%      2.780454
# 50%      3.043458
# 75%      3.206314
# max      3.387055
# Name: len_final, dtype: float64
# ----------------------
#  engineering and technology
# Disciplines: ['Environmental engineering', 'Other engineering and technologies', 'Electrical engineering, electronic engineering, information engineering', 'Materials engineering', 'Chemical engineering', 'Nano-technology', 'Civil engineering', 'Medical engineering', 'Environmental biotechnology', 'Mechanical engineering', 'Industrial Biotechnology']
# Count information
#  count       11.000000
# mean     22871.818182
# std      17188.916172
# min       1702.000000
# 25%      10421.500000
# 50%      17390.000000
# 75%      36200.000000
# max      55373.000000
# Name: ABSTRACT, dtype: float64
# Nb labels information
#  count    11.000000
# mean      3.487020
# std       0.333011
# min       2.869740
# 25%       3.304882
# 50%       3.431288
# 75%       3.674976
# max       4.135825
# Name: len_final, dtype: float64
# ----------------------
#  medical and health sciences
# Disciplines: ['Basic medicine', 'Clinical medicine', 'Health sciences', 'Health biotechnology']
# Count information
#  count         4.000000
# mean      62669.500000
# std       51777.775609
# min         376.000000
# 25%       39518.500000
# 50%       62302.500000
# 75%       85453.500000
# max      125697.000000
# Name: ABSTRACT, dtype: float64
# Nb labels information
#  count    4.000000
# mean     2.931298
# std      0.664172
# min      2.232814
# 25%      2.652171
# 50%      2.829966
# 75%      3.109092
# max      3.832447
# Name: len_final, dtype: float64
# ----------------------
#  humanities
# Disciplines: ['Literature', 'Art (arts, history of arts, performing arts, music)', 'History', 'Philosophy and ethics', 'Religion', 'Other humanities', 'Languages and linguistics', 'Archaeology']
# Count information
#  count       8.000000
# mean     1404.750000
# std       982.359368
# min       500.000000
# 25%       628.750000
# 50%      1008.500000
# 75%      2135.000000
# max      3190.000000
# Name: ABSTRACT, dtype: float64
# Nb labels information
#  count    8.000000
# mean     2.819185
# std      0.271680
# min      2.485313
# 25%      2.568023
# 50%      2.802190
# 75%      3.080187
# max      3.162075
# Name: len_final, dtype: float64
# ----------------------
#  agricultural sciences
# Disciplines: ['Agriculture, forestry, and fisheries', 'Veterinary science', 'Animal and dairy science', 'Other agricultural sciences']
# Count information
#  count        4.000000
# mean      4776.500000
# std       4972.873381
# min       1501.000000
# 25%       1875.250000
# 50%       2738.000000
# 75%       5639.250000
# max      12129.000000
# Name: ABSTRACT, dtype: float64
# Nb labels information
#  count    4.000000
# mean     3.128487
# std      0.637846
# min      2.775029
# 25%      2.793757
# 50%      2.827488
# 75%      3.162218
# max      4.083944
# Name: len_final, dtype: float64
# Total disciplines over threshold: 0

# %% [markdown]
# ## ChatGPT10

# %%
chatgpt10 = pd.read_csv('data_gpt10.csv')

# %%
chatgpt10['final_disciplines'] = chatgpt10.final_disciplines.apply(lambda x: x.split(';'))

# %%
chatgpt10['len_final'] = chatgpt10.final_disciplines.apply(len)

# %%
chatgpt10.len_final.describe()
# Out:
# count    191.000000
# mean       3.219895
# std        1.144240
# min        1.000000
# 25%        2.000000
# 50%        3.000000
# 75%        4.000000
# max        5.000000
# Name: len_final, dtype: float64

# %%
describe_area(chatgpt10)
# Out:
# ----------------------
#  natural sciences
# Disciplines: ['Mathematics', 'Biological sciences', 'Earth and related environmental sciences', 'Chemical sciences', 'Physical sciences', 'Computer and information sciences']
# Count information
#  count     6.000000
# mean     20.500000
# std       8.312641
# min      13.000000
# 25%      14.750000
# 50%      17.000000
# 75%      26.750000
# max      32.000000
# Name: ABSTRACT, dtype: float64
# Nb labels information
#  count    6.000000
# mean     3.757345
# std      0.483119
# min      3.000000
# 25%      3.560202
# 50%      3.746606
# 75%      4.086538
# max      4.352941
# Name: len_final, dtype: float64
# ----------------------
#  engineering and technology
# Disciplines: ['Environmental engineering', 'Other engineering and technologies', 'Electrical engineering, electronic engineering, information engineering', 'Environmental biotechnology', 'Civil engineering', 'Chemical engineering', 'Mechanical engineering', 'Materials engineering', 'Medical engineering', 'Industrial Biotechnology', 'Nano-technology']
# Count information
#  count    11.000000
# mean     13.727273
# std       3.663084
# min      10.000000
# 25%      11.000000
# 50%      12.000000
# 75%      15.000000
# max      22.000000
# Name: ABSTRACT, dtype: float64
# Nb labels information
#  count    11.000000
# mean      3.904090
# std       0.324765
# min       3.125000
# 25%       3.825758
# 50%       4.000000
# 75%       4.146465
# max       4.214286
# Name: len_final, dtype: float64
# ----------------------
#  agricultural sciences
# Disciplines: ['Agriculture, forestry, and fisheries', 'Animal and dairy science', 'Veterinary science', 'Other agricultural sciences']
# Count information
#  count     4.000000
# mean     11.500000
# std       1.914854
# min      10.000000
# 25%      10.000000
# 50%      11.000000
# 75%      12.500000
# max      14.000000
# Name: ABSTRACT, dtype: float64
# Nb labels information
#  count    4.000000
# mean     3.491071
# std      0.273138
# min      3.214286
# 25%      3.278571
# 50%      3.500000
# 75%      3.712500
# max      3.750000
# Name: len_final, dtype: float64
# ----------------------
#  social sciences
# Disciplines: ['Sociology', 'Media and communications', 'Educational sciences', 'Social and economic geography', 'Law', 'Psychology', 'Economics and business', 'Political Science', 'Other social sciences']
# Count information
#  count     9.000000
# mean     14.555556
# std       6.267199
# min      10.000000
# 25%      11.000000
# 50%      13.000000
# 75%      15.000000
# max      30.000000
# Name: ABSTRACT, dtype: float64
# Nb labels information
#  count    9.000000
# mean     3.499730
# std      0.266506
# min      3.117647
# 25%      3.272727
# 50%      3.533333
# 75%      3.666667
# max      3.846154
# Name: len_final, dtype: float64
# ----------------------
#  humanities
# Disciplines: ['Other humanities', 'Languages and linguistics', 'Literature', 'Art (arts, history of arts, performing arts, music)', 'History', 'Archaeology', 'Philosophy and ethics', 'Religion']
# Count information
#  count     8.000000
# mean     13.375000
# std       2.615203
# min      10.000000
# 25%      12.000000
# 50%      13.000000
# 75%      14.000000
# max      19.000000
# Name: ABSTRACT, dtype: float64
# Nb labels information
#  count    8.000000
# mean     3.048217
# std      0.205114
# min      2.769231
# 25%      2.883333
# 50%      3.076923
# 75%      3.171992
# max      3.357143
# Name: len_final, dtype: float64
# ----------------------
#  medical and health sciences
# Disciplines: ['Basic medicine', 'Health sciences', 'Clinical medicine', 'Health biotechnology']
# Count information
#  count     4.000000
# mean     14.250000
# std       5.057997
# min      10.000000
# 25%      10.000000
# 50%      13.500000
# 75%      17.750000
# max      20.000000
# Name: ABSTRACT, dtype: float64
# Nb labels information
#  count    4.000000
# mean     3.981618
# std      0.209992
# min      3.700000
# 25%      3.887500
# 50%      4.025000
# 75%      4.119118
# max      4.176471
# Name: len_final, dtype: float64
# Total disciplines over threshold: 0

# %% [markdown]
# ## ChatGPT50

# %%
chatgpt50 = pd.read_csv('data_gpt50.csv')

# %%
chatgpt50['final_disciplines'] = chatgpt50.final_disciplines.apply(lambda x: x.split(';'))

# %%
chatgpt50['len_final'] = chatgpt50.final_disciplines.apply(len)

# %%
chatgpt50.len_final.describe()
# Out:
# count    1569.000000
# mean        1.964946
# std         0.966622
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         2.000000
# max         5.000000
# Name: len_final, dtype: float64

# %%
describe_area(chatgpt50)
# Out:
# ----------------------
#  humanities
# Disciplines: ['Other humanities', 'Archaeology', 'History', 'Philosophy and ethics', 'Art (arts, history of arts, performing arts, music)', 'Languages and linguistics', 'Literature', 'Religion']
# Count information
#  count     8.000000
# mean     52.750000
# std       9.207916
# min      41.000000
# 25%      46.500000
# 50%      52.000000
# 75%      57.250000
# max      70.000000
# Name: ABSTRACT, dtype: float64
# Nb labels information
#  count    8.000000
# mean     2.201953
# std      0.138094
# min      1.975610
# 25%      2.137943
# 50%      2.185266
# 75%      2.303571
# max      2.385965
# Name: len_final, dtype: float64
# ----------------------
#  engineering and technology
# Disciplines: ['Environmental engineering', 'Chemical engineering', 'Mechanical engineering', 'Other engineering and technologies', 'Electrical engineering, electronic engineering, information engineering', 'Materials engineering', 'Civil engineering', 'Nano-technology', 'Environmental biotechnology', 'Medical engineering', 'Industrial Biotechnology']
# Count information
#  count     11.000000
# mean      65.909091
# std       22.638262
# min       41.000000
# 25%       47.500000
# 50%       57.000000
# 75%       82.000000
# max      107.000000
# Name: ABSTRACT, dtype: float64
# Nb labels information
#  count    11.000000
# mean      2.429259
# std       0.227472
# min       2.024390
# 25%       2.313450
# 50%       2.369565
# 75%       2.571566
# max       2.850575
# Name: len_final, dtype: float64
# ----------------------
#  social sciences
# Disciplines: ['Educational sciences', 'Psychology', 'Law', 'Media and communications', 'Sociology', 'Other social sciences', 'Economics and business', 'Social and economic geography', 'Political Science']
# Count information
#  count      9.000000
# mean      78.444444
# std       31.277432
# min       45.000000
# 25%       55.000000
# 50%       60.000000
# 75%      114.000000
# max      120.000000
# Name: ABSTRACT, dtype: float64
# Nb labels information
#  count    9.000000
# mean     2.371481
# std      0.168225
# min      2.166667
# 25%      2.229167
# 50%      2.400000
# 75%      2.500000
# max      2.623932
# Name: len_final, dtype: float64
# ----------------------
#  medical and health sciences
# Disciplines: ['Health sciences', 'Basic medicine', 'Clinical medicine', 'Health biotechnology']
# Count information
#  count      4.000000
# mean      93.000000
# std       48.545511
# min       29.000000
# 25%       79.250000
# 50%       98.000000
# 75%      111.750000
# max      147.000000
# Name: ABSTRACT, dtype: float64
# Nb labels information
#  count    4.000000
# mean     2.614117
# std      0.123168
# min      2.517241
# 25%      2.522167
# 50%      2.579613
# 75%      2.671562
# max      2.780000
# Name: len_final, dtype: float64
# ----------------------
#  natural sciences
# Disciplines: ['Earth and related environmental sciences', 'Computer and information sciences', 'Physical sciences', 'Chemical sciences', 'Biological sciences', 'Mathematics']
# Count information
#  count      6.000000
# mean     111.166667
# std       47.207697
# min       57.000000
# 25%       89.000000
# 50%       98.500000
# 75%      124.500000
# max      194.000000
# Name: ABSTRACT, dtype: float64
# Nb labels information
#  count    6.000000
# mean     2.510484
# std      0.121294
# min      2.315789
# 25%      2.441952
# 50%      2.552444
# 75%      2.604401
# max      2.615385
# Name: len_final, dtype: float64
# ----------------------
#  agricultural sciences
# Disciplines: ['Veterinary science', 'Animal and dairy science', 'Other agricultural sciences', 'Agriculture, forestry, and fisheries']
# Count information
#  count     4.000000
# mean     47.750000
# std       6.849574
# min      40.000000
# 25%      43.750000
# 50%      47.500000
# 75%      51.500000
# max      56.000000
# Name: ABSTRACT, dtype: float64
# Nb labels information
#  count    4.000000
# mean     2.166409
# std      0.041915
# min      2.125000
# 25%      2.138393
# 50%      2.160317
# 75%      2.188333
# max      2.220000
# Name: len_final, dtype: float64
# Total disciplines over threshold: 0
