# %%
import pandas as pd

# %%
sep_BERT_SVM = ' '*4
sep_gpt = ' '*5
report = pd.read_csv('BERT-SVM/1000/bert-base.txt', sep=sep_BERT_SVM, )
# Out:
# <ipython-input-40-ae5cdae7d7bb>:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   report = pd.read_csv('BERT-SVM/1000/bert-base.txt', sep=sep_BERT_SVM, )

# %%
report
# Out:
#                                            discipline   precision   recall  \
# 0                Agriculture, forestry, and fisheries      0.4367   0.8047
# 1                            Animal and dairy science      0.4355   0.8780
# 2                                         Archaeology      0.4004   0.8574
# 3   Art (arts, history of arts, performing arts, m...      0.5176   0.3582
# 4                                      Basic medicine      0.6700   0.4169
# 5                                 Biological sciences      0.8510   0.7254
# 6                                Chemical engineering      0.4966   0.6873
# 7                                   Chemical sciences      0.8407   0.8109
# 8                                   Civil engineering      0.5964   0.7510
# 9                                   Clinical medicine      0.9348   0.7251
# 10                  Computer and information sciences      0.7465   0.7269
# 11           Earth and related environmental sciences      0.8560   0.6561
# 12                             Economics and business      0.8391   0.6712
# 13                               Educational sciences      0.7110   0.7462
# 14  Electrical engineering, electronic engineering...      0.8349   0.6984
# 15                        Environmental biotechnology      0.4188   0.4731
# 16                          Environmental engineering      0.6741   0.6578
# 17                               Health biotechnology      0.0276   0.9069
# 18                                    Health sciences      0.7726   0.5279
# 19                                            History      0.7421   0.3146
# 20                           Industrial Biotechnology      0.2058   0.8190
# 21                          Languages and linguistics      0.4678   0.7646
# 22                                                Law      0.4008   0.8470
# 23                                         Literature      0.6210   0.6258
# 24                              Materials engineering      0.7986   0.8313
# 25                                        Mathematics      0.7647   0.7398
# 26                             Mechanical engineering      0.7551   0.5108
# 27                           Media and communications      0.4059   0.6004
# 28                                Medical engineering      0.2349   0.6157
# 29                                    Nano-technology      0.3883   0.7608
# 30                        Other agricultural sciences      0.1902   0.7275
# 31                 Other engineering and technologies      0.7746   0.2374
# 32                                   Other humanities      0.2181   0.2120
# 33                              Other social sciences      0.4734   0.6221
# 34                              Philosophy and ethics      0.5724   0.6568
# 35                                  Physical sciences      0.8133   0.7102
# 36                                  Political Science      0.7032   0.6114
# 37                                         Psychology      0.7653   0.6261
# 38                                           Religion      0.4239   0.8336
# 39                      Social and economic geography      0.7359   0.4583
# 40                                          Sociology      0.7030   0.4553
# 41                                 Veterinary science      0.3610   0.8052
# 42                                          micro avg      0.7282   0.6608
# 43                                          macro avg      0.5852   0.6539
# 44                                       weighted avg      0.7725   0.6608
# 45                                        samples avg      0.7705   0.7185
#
#      f1-score   support
# 0      0.5662     12129
# 1      0.5822      2000
# 2      0.5459       638
# 3      0.4234      1234
# 4      0.5140     72039
# 5      0.7832    102494
# 6      0.5766     13813
# 7      0.8255     77864
# 8      0.6649     14688
# 9      0.8167    125697
# 10     0.7366     35393
# 11     0.7429     57881
# 12     0.7458     25366
# 13     0.7282      7171
# 14     0.7606     38592
# 15     0.4443      7030
# 16     0.6658     39923
# 17     0.0536       376
# 18     0.6273     52566
# 19     0.4419      2168
# 20     0.3289      1702
# 21     0.5804      3190
# 22     0.5441      2117
# 23     0.6234       783
# 24     0.8146     55373
# 25     0.7520     22052
# 26     0.6094     25287
# 27     0.4844      3611
# 28     0.3400      3984
# 29     0.5142     17390
# 30     0.3016      1501
# 31     0.3634     33808
# 32     0.2150       500
# 33     0.5376      2302
# 34     0.6117      2124
# 35     0.7582     61304
# 36     0.6541      4825
# 37     0.6887     26081
# 38     0.5620       601
# 39     0.5648     12512
# 40     0.5527     14140
# 41     0.4985      3476
# 42     0.6929    987725
# 43     0.5749    987725
# 44     0.6988    987725
# 45     0.6980    987725

# %%
report.columns = [column.strip() for column in report.columns]

# %%
report.to_csv('report_sample.csv', index=False)

# %%
report['f1-score'].mean()
# Out:
# 0.5828239130434782

# %%
report.disciplines = report.discipline.str.strip().str.lower()
# Out:
# <ipython-input-45-2795d646db72>:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   report.disciplines = report.discipline.str.strip().str.lower()

# %%
report = report[['discipline', 'precision', 'recall', 'f1-score']]

# %%
import json
with open('../discipline_structure.json', 'r') as f:
    data = json.load(f)

# %%
data_simplified = {key1: list(value.keys()) for key1, value in data.items()}

# %%
data_simplified_reversed = {el:key for key, value in data_simplified.items() for el in value}

# %%
data_simplified_reversed
# Out:
# {'agriculture, forestry, and fisheries': 'agricultural sciences',
#  'animal and dairy science': 'agricultural sciences',
#  'veterinary science': 'agricultural sciences',
#  'agricultural biotechnology': 'agricultural sciences',
#  'other agricultural sciences': 'agricultural sciences',
#  'civil engineering': 'engineering and technology',
#  'electrical engineering, electronic engineering, information engineering': 'engineering and technology',
#  'mechanical engineering': 'engineering and technology',
#  'chemical engineering': 'engineering and technology',
#  'materials engineering': 'engineering and technology',
#  'medical engineering': 'engineering and technology',
#  'environmental engineering': 'engineering and technology',
#  'environmental biotechnology': 'engineering and technology',
#  'industrial biotechnology': 'engineering and technology',
#  'nano-technology': 'engineering and technology',
#  'other engineering and technologies': 'engineering and technology',
#  'history': 'humanities',
#  'archaeology': 'humanities',
#  'languages and linguistics': 'humanities',
#  'literature': 'humanities',
#  'philosophy and ethics': 'humanities',
#  'religion': 'humanities',
#  'arts (arts, history of arts, performing arts, music)': 'humanities',
#  'other humanities': 'humanities',
#  'basic medicine': 'medical and health sciences',
#  'clinical medicine': 'medical and health sciences',
#  'health sciences': 'medical and health sciences',
#  'health biotechnology': 'medical and health sciences',
#  'other medical sciences': 'medical and health sciences',
#  'mathematics': 'natural sciences',
#  'computer and information sciences': 'natural sciences',
#  'physical sciences': 'natural sciences',
#  'chemical sciences': 'natural sciences',
#  'earth and related environmental sciences': 'natural sciences',
#  'biological sciences': 'natural sciences',
#  'other natural sciences': 'natural sciences',
#  'psychology': 'social sciences',
#  'economics and business': 'social sciences',
#  'educational sciences': 'social sciences',
#  'sociology': 'social sciences',
#  'law': 'social sciences',
#  'political science': 'social sciences',
#  'social and economic geography': 'social sciences',
#  'media and communications': 'social sciences',
#  'other social sciences': 'social sciences'}

# %%
report.discipline = report.discipline.str.lower().str.replace('art ', 'arts ')#.str.replace('psychology', 'psychology and cognitive sciences')

def get_area(discipline):
    return data_simplified_reversed[discipline.lower()] if discipline.lower() in data_simplified_reversed else discipline

report['area'] = report.discipline.apply(get_area)
# Out:
# <ipython-input-53-d0975e4fd8e5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report.discipline = report.discipline.str.lower().str.replace('art ', 'arts ')#.str.replace('psychology', 'psychology and cognitive sciences')

# %%
report.groupby('area')[['precision', 'recall', 'f1-score']].mean()
# Out:
#                              precision    recall  f1-score
# area
# agricultural sciences         0.355850  0.803850  0.487125
# engineering and technology    0.561645  0.640236  0.552973
# humanities                    0.495412  0.577875  0.500463
# macro avg                     0.585200  0.653900  0.574900
# medical and health sciences   0.601250  0.644200  0.502900
# micro avg                     0.728200  0.660800  0.692900
# natural sciences              0.812033  0.728217  0.766400
# samples avg                   0.770500  0.718500  0.698000
# social sciences               0.637511  0.626444  0.611156
# weighted avg                  0.772500  0.660800  0.698800

# %%
sum(report.recall - report.precision > 0)
# Out:
# 22
