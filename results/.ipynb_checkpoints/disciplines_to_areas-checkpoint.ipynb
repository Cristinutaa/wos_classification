# %%
import pandas as pd

# %%
report = pd.read_csv('BERT-SVM/100000/ssci-bert2.txt', sep='    ', )
# Out:
# <ipython-input-5-73b73cc6cac3>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   report = pd.read_csv('BERT-SVM/100000/ssci-bert2.txt', sep='    ', )

# %%
report
# Out:
#                                            discipline   precision    recall  \
# 0                Agriculture, forestry, and fisheries      0.6180    0.8180
# 1                            Animal and dairy science      0.7011    0.8035
# 2                                         Archaeology      0.6398    0.7602
# 3   Art (arts, history of arts, performing arts, m...      0.6890    0.3088
# 4                                      Basic medicine      0.6880    0.8271
# 5                                 Biological sciences      0.8487    0.8626
# 6                                Chemical engineering      0.6528    0.7700
# 7                                   Chemical sciences      0.8727    0.8788
# 8                                   Civil engineering      0.7538    0.7863
# 9                                   Clinical medicine      0.9080    0.9336
# 10                  Computer and information sciences      0.7804    0.8099
# 11           Earth and related environmental sciences      0.8727    0.8101
# 12                             Economics and business      0.8551    0.8077
# 13                               Educational sciences      0.7565    0.8180
# 14  Electrical engineering, electronic engineering...      0.8354    0.8742
# 15                        Environmental biotechnology      0.5060    0.6634
# 16                          Environmental engineering      0.7594    0.8222
# 17                               Health biotechnology      0.2709    0.6809
# 18                                    Health sciences      0.6958    0.8476
# 19                                            History      0.6806    0.5240
# 20                           Industrial Biotechnology      0.4542    0.7456
# 21                          Languages and linguistics      0.7260    0.7574
# 22                                                Law      0.7344    0.7081
# 23                                         Literature      0.6938    0.5121
# 24                              Materials engineering      0.8578    0.8747
# 25                                        Mathematics      0.7772    0.7971
# 26                             Mechanical engineering      0.7226    0.7800
# 27                           Media and communications      0.6689    0.5622
# 28                                Medical engineering      0.4925    0.6413
# 29                                    Nano-technology      0.4991    0.8270
# 30                        Other agricultural sciences      0.5416    0.4903
# 31                 Other engineering and technologies      0.6609    0.6982
# 32                                   Other humanities      0.0000    0.0000
# 33                              Other social sciences      0.7430    0.5778
# 34                              Philosophy and ethics      0.7146    0.6733
# 35                                  Physical sciences      0.8665    0.8057
# 36                                  Political Science      0.7633    0.7038
# 37                                         Psychology      0.7807    0.7817
# 38                                           Religion      0.6221    0.6273
# 39                      Social and economic geography      0.7431    0.6662
# 40                                          Sociology      0.6744    0.6873
# 41                                 Veterinary science      0.6635    0.7949
# 42                                          micro avg      0.7859    0.8294
# 43                                          macro avg      0.6854    0.7171
# 44                                       weighted avg      0.7944    0.8294
# 45                                        samples avg      0.8164    0.8697
#
#      f1-score   support
# 0      0.7041     12129
# 1      0.7488      2000
# 2      0.6948       638
# 3      0.4264      1234
# 4      0.7512     72039
# 5      0.8556    102494
# 6      0.7066     13813
# 7      0.8757     77864
# 8      0.7697     14688
# 9      0.9206    125697
# 10     0.7949     35393
# 11     0.8402     57881
# 12     0.8307     25366
# 13     0.7861      7171
# 14     0.8544     38592
# 15     0.5741      7030
# 16     0.7896     39923
# 17     0.3876       376
# 18     0.7642     52566
# 19     0.5921      2168
# 20     0.5645      1702
# 21     0.7413      3190
# 22     0.7210      2117
# 23     0.5893       783
# 24     0.8662     55373
# 25     0.7870     22052
# 26     0.7502     25287
# 27     0.6109      3611
# 28     0.5571      3984
# 29     0.6225     17390
# 30     0.5147      1501
# 31     0.6791     33808
# 32     0.0000       500
# 33     0.6500      2302
# 34     0.6933      2124
# 35     0.8350     61304
# 36     0.7324      4825
# 37     0.7812     26081
# 38     0.6247       601
# 39     0.7026     12512
# 40     0.6808     14140
# 41     0.7233      3476
# 42     0.8071    987725
# 43     0.6927    987725
# 44     0.8093    987725
# 45     0.8091    987725

# %%
report.columns = [column.strip() for column in report.columns]

# %%
report.to_csv('report_sample.csv', index=False)

# %%
report['f1-score'].mean()
# Out:
# 0.7002760869565215

# %%
report.disciplines = report.discipline.str.strip().str.lower()
# Out:
# <ipython-input-10-2795d646db72>:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   report.disciplines = report.discipline.str.strip().str.lower()

# %%
report = report[['discipline', 'precision', 'recall', 'f1-score']]

# %%
import json
with open('../discipline_structure.json', 'r') as f:
    data = json.load(f)

# %%
data_simplified = {key1: list(value.keys()) for key1, value in data.items()}

# %%
data_simplified
# Out:
# {'agricultural sciences': ['agriculture, forestry, and fisheries',
#   'animal and dairy science',
#   'veterinary science',
#   'agricultural biotechnology',
#   'other agricultural sciences'],
#  'engineering and technology': ['civil engineering',
#   'electrical engineering, electronic engineering, information engineering',
#   'mechanical engineering',
#   'chemical engineering',
#   'materials engineering',
#   'medical engineering',
#   'environmental engineering',
#   'environmental biotechnology',
#   'industrial biotechnology',
#   'nano-technology',
#   'other engineering and technologies'],
#  'humanities': ['history',
#   'archaeology',
#   'languages and linguistics',
#   'literature',
#   'philosophy and ethics',
#   'religion',
#   'arts (arts, history of arts, performing arts, music)',
#   'other humanities'],
#  'medical and health sciences': ['basic medicine',
#   'clinical medicine',
#   'health sciences',
#   'health biotechnology',
#   'other medical sciences'],
#  'natural sciences': ['mathematics',
#   'computer and information sciences',
#   'physical sciences',
#   'chemical sciences',
#   'earth and related environmental sciences',
#   'biological sciences',
#   'other natural sciences'],
#  'social sciences': ['psychology',
#   'economics and business',
#   'educational sciences',
#   'sociology',
#   'law',
#   'political science',
#   'social and economic geography',
#   'media and communications',
#   'other social sciences']}

# %%
data_simplified_reversed = {el:key for key, value in data_simplified.items() for el in value}

# %%
data_simplified_reversed
# Out:
# {'agriculture, forestry, and fisheries': 'agricultural sciences',
#  'animal and dairy science': 'agricultural sciences',
#  'veterinary science': 'agricultural sciences',
#  'agricultural biotechnology': 'agricultural sciences',
#  'other agricultural sciences': 'agricultural sciences',
#  'civil engineering': 'engineering and technology',
#  'electrical engineering, electronic engineering, information engineering': 'engineering and technology',
#  'mechanical engineering': 'engineering and technology',
#  'chemical engineering': 'engineering and technology',
#  'materials engineering': 'engineering and technology',
#  'medical engineering': 'engineering and technology',
#  'environmental engineering': 'engineering and technology',
#  'environmental biotechnology': 'engineering and technology',
#  'industrial biotechnology': 'engineering and technology',
#  'nano-technology': 'engineering and technology',
#  'other engineering and technologies': 'engineering and technology',
#  'history': 'humanities',
#  'archaeology': 'humanities',
#  'languages and linguistics': 'humanities',
#  'literature': 'humanities',
#  'philosophy and ethics': 'humanities',
#  'religion': 'humanities',
#  'arts (arts, history of arts, performing arts, music)': 'humanities',
#  'other humanities': 'humanities',
#  'basic medicine': 'medical and health sciences',
#  'clinical medicine': 'medical and health sciences',
#  'health sciences': 'medical and health sciences',
#  'health biotechnology': 'medical and health sciences',
#  'other medical sciences': 'medical and health sciences',
#  'mathematics': 'natural sciences',
#  'computer and information sciences': 'natural sciences',
#  'physical sciences': 'natural sciences',
#  'chemical sciences': 'natural sciences',
#  'earth and related environmental sciences': 'natural sciences',
#  'biological sciences': 'natural sciences',
#  'other natural sciences': 'natural sciences',
#  'psychology': 'social sciences',
#  'economics and business': 'social sciences',
#  'educational sciences': 'social sciences',
#  'sociology': 'social sciences',
#  'law': 'social sciences',
#  'political science': 'social sciences',
#  'social and economic geography': 'social sciences',
#  'media and communications': 'social sciences',
#  'other social sciences': 'social sciences'}

# %%
report.discipline = report.discipline.str.replace('art ', 'arts ')#.str.replace('psychology', 'psychology and cognitive sciences')

def get_area(discipline):
    return data_simplified_reversed[discipline.lower()] if discipline.lower() in data_simplified_reversed else discipline

report['area'] = report.discipline.apply(get_area)
# Out:
# <ipython-input-17-d579eb4480d4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report.discipline = report.discipline.str.replace('art ', 'arts ')#.str.replace('psychology', 'psychology and cognitive sciences')

# %%
report.groupby('area')[['precision', 'recall', 'f1-score']].mean()
# Out:
#                                                     precision    recall  \
# area
# Art (arts, history of arts, performing arts, mu...   0.689000  0.308800
# agricultural sciences                                0.631050  0.726675
# engineering and technology                           0.654045  0.771173
# humanities                                           0.582414  0.550614
# macro avg                                            0.685400  0.717100
# medical and health sciences                          0.640675  0.822300
# micro avg                                            0.785900  0.829400
# natural sciences                                     0.836367  0.827367
# samples avg                                          0.816400  0.869700
# social sciences                                      0.746600  0.701422
# weighted avg                                         0.794400  0.829400
#
#                                                     f1-score
# area
# Art (arts, history of arts, performing arts, mu...  0.426400
# agricultural sciences                               0.672725
# engineering and technology                          0.703091
# humanities                                          0.562214
# macro avg                                           0.692700
# medical and health sciences                         0.705900
# micro avg                                           0.807100
# natural sciences                                    0.831400
# samples avg                                         0.809100
# social sciences                                     0.721744
# weighted avg                                        0.809300

# %%
report
# Out:
#                                            discipline  precision  recall  \
# 0                agriculture, forestry, and fisheries       0.42    0.50
# 1                            animal and dairy science       0.91    0.71
# 2                                         archaeology       0.78    0.58
# 3   arts (arts, history of arts, performing arts, ...       0.42    0.57
# 4                                      basic medicine       0.25    0.94
# 5                                 biological sciences       0.57    0.62
# 6                                chemical engineering       0.43    0.82
# 7                                   chemical sciences       0.69    0.30
# 8                                   civil engineering       0.36    0.94
# 9                                   clinical medicine       0.28    0.95
# 10                  computer and information sciences       0.12    0.15
# 11           earth and related environmental sciences       0.26    0.59
# 12                             economics and business       0.47    0.47
# 13                               educational sciences       0.27    0.30
# 14  electrical engineering, electronic engineering...       0.17    0.80
# 15                        environmental biotechnology       1.00    0.07
# 16                          environmental engineering       0.00    0.00
# 17                               health biotechnology       0.00    0.00
# 18                                    health sciences       0.13    0.20
# 19                                            history       0.41    0.50
# 20                           industrial biotechnology       0.18    0.25
# 21                          languages and linguistics       0.67    0.15
# 22                                                law       0.44    0.73
# 23                                         literature       0.37    0.58
# 24                              materials engineering       0.30    0.95
# 25                                        mathematics       0.60    0.21
# 26                             mechanical engineering       0.29    0.83
# 27                           media and communications       0.16    0.50
# 28                                medical engineering       0.23    1.00
# 29                                    nano-technology       0.38    0.91
# 30                        other agricultural sciences       0.00    0.00
# 31                 other engineering and technologies       0.09    0.14
# 32                                   other humanities       0.33    0.05
# 33                              other social sciences       0.14    0.36
# 34                              philosophy and ethics       0.43    0.30
# 35                                  physical sciences       0.33    0.18
# 36                                  political science       0.45    0.50
# 37                                         psychology       0.60    0.60
# 38                                           religion       0.69    0.69
# 39                      social and economic geography       0.22    0.31
# 40                                          sociology       0.46    0.53
# 41                                 veterinary science       0.40    0.40
#
#     f1-score                         area
# 0       0.45        agricultural sciences
# 1       0.80        agricultural sciences
# 2       0.67                   humanities
# 3       0.48                   humanities
# 4       0.40  medical and health sciences
# 5       0.60             natural sciences
# 6       0.56   engineering and technology
# 7       0.42             natural sciences
# 8       0.52   engineering and technology
# 9       0.43  medical and health sciences
# 10      0.13             natural sciences
# 11      0.36             natural sciences
# 12      0.47              social sciences
# 13      0.29              social sciences
# 14      0.28   engineering and technology
# 15      0.13   engineering and technology
# 16      0.00   engineering and technology
# 17      0.00  medical and health sciences
# 18      0.16  medical and health sciences
# 19      0.45                   humanities
# 20      0.21   engineering and technology
# 21      0.25                   humanities
# 22      0.55              social sciences
# 23      0.45                   humanities
# 24      0.45   engineering and technology
# 25      0.32             natural sciences
# 26      0.43   engineering and technology
# 27      0.24              social sciences
# 28      0.38   engineering and technology
# 29      0.54   engineering and technology
# 30      0.00        agricultural sciences
# 31      0.11   engineering and technology
# 32      0.09                   humanities
# 33      0.21              social sciences
# 34      0.35                   humanities
# 35      0.23             natural sciences
# 36      0.48              social sciences
# 37      0.60              social sciences
# 38      0.69                   humanities
# 39      0.26              social sciences
# 40      0.49              social sciences
# 41      0.40        agricultural sciences
